# %% [markdown]
# # Run Badlands Models

# %%
from badlands.model import Model as badlandsModel

# initialise model
model = badlandsModel()
model.load_xml('../InputFiles/Alps100ka.xml')
# model.load_xml('../InputFiles/Alpshort.xml')
# Out:
# loading ice curve
# loading ice map

# %%
maxtime = 100000

# %%
model.run_to_time(maxtime,verbose=False)
# Out:
#    - Writing outputs (0.35 seconds; tNow = 0.0)
#    - Compute flexural isostasy 3.29 seconds
#    - Writing outputs (0.30 seconds; tNow = 1000.0)
#    - Compute flexural isostasy 3.21 seconds
#    - Writing outputs (0.30 seconds; tNow = 2000.0)
#    - Compute flexural isostasy 3.43 seconds
#    - Writing outputs (0.33 seconds; tNow = 3000.0)
#    - Compute flexural isostasy 5.39 seconds
#    - Writing outputs (0.32 seconds; tNow = 4000.0)
#    - Compute flexural isostasy 3.03 seconds
#    - Writing outputs (0.30 seconds; tNow = 5000.0)
#    - Compute flexural isostasy 3.12 seconds
#    - Writing outputs (0.31 seconds; tNow = 6000.0)
#    - Compute flexural isostasy 3.12 seconds
#    - Writing outputs (0.31 seconds; tNow = 7000.0)
#    - Compute flexural isostasy 3.24 seconds
#    - Writing outputs (0.33 seconds; tNow = 8000.0)
#    - Compute flexural isostasy 3.30 seconds
#    - Writing outputs (0.34 seconds; tNow = 9000.0)
#    - Compute flexural isostasy 3.02 seconds
#    - Writing outputs (0.32 seconds; tNow = 10000.0)
#    - Compute flexural isostasy 3.33 seconds
#    - Writing outputs (0.30 seconds; tNow = 11000.0)
#    - Compute flexural isostasy 3.35 seconds
#    - Writing outputs (0.34 seconds; tNow = 12000.0)
#    - Compute flexural isostasy 3.50 seconds
#    - Writing outputs (0.33 seconds; tNow = 13000.0)
#    - Compute flexural isostasy 3.99 seconds
#    - Writing outputs (0.33 seconds; tNow = 14000.0)
#    - Compute flexural isostasy 3.75 seconds
#    - Writing outputs (0.33 seconds; tNow = 15000.0)
#    - Compute flexural isostasy 3.14 seconds
#    - Writing outputs (0.30 seconds; tNow = 16000.0)
#    - Compute flexural isostasy 2.95 seconds
#    - Writing outputs (0.30 seconds; tNow = 17000.0)
#    - Compute flexural isostasy 3.04 seconds
#    - Writing outputs (0.31 seconds; tNow = 18000.0)
#    - Compute flexural isostasy 3.06 seconds
#    - Writing outputs (0.32 seconds; tNow = 19000.0)
#    - Compute flexural isostasy 3.40 seconds
#    - Writing outputs (0.34 seconds; tNow = 20000.0)
#    - Compute flexural isostasy 3.07 seconds
#    - Writing outputs (0.31 seconds; tNow = 21000.0)
#    - Compute flexural isostasy 4.10 seconds
#    - Writing outputs (0.32 seconds; tNow = 22000.0)
#    - Compute flexural isostasy 4.35 seconds
#    - Writing outputs (0.33 seconds; tNow = 23000.0)
#    - Compute flexural isostasy 4.14 seconds
#    - Writing outputs (0.32 seconds; tNow = 24000.0)
#    - Compute flexural isostasy 3.40 seconds
#    - Writing outputs (0.30 seconds; tNow = 25000.0)
#    - Compute flexural isostasy 3.04 seconds
#    - Writing outputs (0.31 seconds; tNow = 26000.0)
#    - Compute flexural isostasy 3.22 seconds
#    - Writing outputs (0.33 seconds; tNow = 27000.0)
#    - Compute flexural isostasy 3.10 seconds
#    - Writing outputs (0.31 seconds; tNow = 28000.0)
#    - Compute flexural isostasy 2.91 seconds
#    - Writing outputs (0.32 seconds; tNow = 29000.0)
#    - Compute flexural isostasy 3.13 seconds
#    - Writing outputs (0.32 seconds; tNow = 30000.0)
#    - Compute flexural isostasy 3.04 seconds
#    - Writing outputs (0.32 seconds; tNow = 31000.0)
#    - Compute flexural isostasy 3.25 seconds
#    - Writing outputs (0.31 seconds; tNow = 32000.0)
#    - Compute flexural isostasy 3.16 seconds
#    - Writing outputs (0.32 seconds; tNow = 33000.0)
#    - Compute flexural isostasy 3.10 seconds
#    - Writing outputs (0.30 seconds; tNow = 34000.0)
#    - Compute flexural isostasy 3.11 seconds
#    - Writing outputs (0.32 seconds; tNow = 35000.0)
#    - Compute flexural isostasy 2.98 seconds
#    - Writing outputs (0.32 seconds; tNow = 36000.0)
#    - Compute flexural isostasy 3.13 seconds
#    - Writing outputs (0.32 seconds; tNow = 37000.0)
#    - Compute flexural isostasy 3.16 seconds
#    - Writing outputs (0.32 seconds; tNow = 38000.0)
#    - Compute flexural isostasy 3.04 seconds
#    - Writing outputs (0.32 seconds; tNow = 39000.0)
#    - Compute flexural isostasy 3.00 seconds
#    - Writing outputs (0.31 seconds; tNow = 40000.0)
#    - Compute flexural isostasy 3.10 seconds
#    - Writing outputs (0.31 seconds; tNow = 41000.0)
#    - Compute flexural isostasy 3.16 seconds
#    - Writing outputs (0.38 seconds; tNow = 42000.0)
#    - Compute flexural isostasy 3.25 seconds
#    - Writing outputs (0.33 seconds; tNow = 43000.0)
#    - Compute flexural isostasy 3.11 seconds
#    - Writing outputs (0.32 seconds; tNow = 44000.0)
#    - Compute flexural isostasy 3.11 seconds
#    - Writing outputs (0.31 seconds; tNow = 45000.0)
#    - Compute flexural isostasy 3.05 seconds
#    - Writing outputs (0.31 seconds; tNow = 46000.0)
#    - Compute flexural isostasy 3.12 seconds
#    - Writing outputs (0.32 seconds; tNow = 47000.0)
#    - Compute flexural isostasy 3.17 seconds
#    - Writing outputs (0.32 seconds; tNow = 48000.0)
#    - Compute flexural isostasy 3.12 seconds
#    - Writing outputs (0.32 seconds; tNow = 49000.0)
#    - Compute flexural isostasy 3.11 seconds
#    - Writing outputs (0.32 seconds; tNow = 50000.0)
#    - Compute flexural isostasy 3.13 seconds
#    - Writing outputs (0.31 seconds; tNow = 51000.0)
#    - Compute flexural isostasy 3.05 seconds
#    - Writing outputs (0.32 seconds; tNow = 52000.0)
#    - Compute flexural isostasy 3.04 seconds
#    - Writing outputs (0.31 seconds; tNow = 53000.0)
#    - Compute flexural isostasy 3.14 seconds
#    - Writing outputs (0.31 seconds; tNow = 54000.0)
#    - Compute flexural isostasy 3.03 seconds
#    - Writing outputs (0.31 seconds; tNow = 55000.0)
#    - Compute flexural isostasy 3.10 seconds
#    - Writing outputs (0.31 seconds; tNow = 56000.0)
#    - Compute flexural isostasy 2.94 seconds
#    - Writing outputs (0.30 seconds; tNow = 57000.0)
#    - Compute flexural isostasy 2.92 seconds
#    - Writing outputs (0.32 seconds; tNow = 58000.0)
#    - Compute flexural isostasy 2.90 seconds
#    - Writing outputs (0.32 seconds; tNow = 59000.0)
#    - Compute flexural isostasy 2.95 seconds
#    - Writing outputs (0.32 seconds; tNow = 60000.0)
#    - Compute flexural isostasy 2.97 seconds
#    - Writing outputs (0.32 seconds; tNow = 61000.0)
#    - Compute flexural isostasy 3.29 seconds
#    - Writing outputs (0.32 seconds; tNow = 62000.0)
#    - Compute flexural isostasy 3.24 seconds
#    - Writing outputs (0.31 seconds; tNow = 63000.0)
#    - Compute flexural isostasy 3.13 seconds
#    - Writing outputs (0.33 seconds; tNow = 64000.0)
#    - Compute flexural isostasy 3.49 seconds
#    - Writing outputs (0.34 seconds; tNow = 65000.0)
#    - Compute flexural isostasy 2.93 seconds
#    - Writing outputs (0.32 seconds; tNow = 66000.0)
#    - Compute flexural isostasy 3.10 seconds
#    - Writing outputs (0.31 seconds; tNow = 67000.0)
#    - Compute flexural isostasy 3.18 seconds
#    - Writing outputs (0.33 seconds; tNow = 68000.0)
#    - Compute flexural isostasy 3.27 seconds
#    - Writing outputs (0.33 seconds; tNow = 69000.0)
#    - Compute flexural isostasy 2.90 seconds
#    - Writing outputs (0.31 seconds; tNow = 70000.0)
#    - Compute flexural isostasy 3.26 seconds
#    - Writing outputs (0.32 seconds; tNow = 71000.0)
#    - Compute flexural isostasy 2.86 seconds
#    - Writing outputs (0.32 seconds; tNow = 72000.0)
#    - Compute flexural isostasy 2.86 seconds
#    - Writing outputs (0.32 seconds; tNow = 73000.0)
#    - Compute flexural isostasy 2.91 seconds
#    - Writing outputs (0.32 seconds; tNow = 74000.0)
#    - Compute flexural isostasy 2.89 seconds
#    - Writing outputs (0.31 seconds; tNow = 75000.0)
#    - Compute flexural isostasy 2.86 seconds
#    - Writing outputs (0.32 seconds; tNow = 76000.0)
#    - Compute flexural isostasy 2.86 seconds
#    - Writing outputs (0.32 seconds; tNow = 77000.0)
#    - Compute flexural isostasy 2.80 seconds
#    - Writing outputs (0.31 seconds; tNow = 78000.0)
#    - Compute flexural isostasy 3.27 seconds
#    - Writing outputs (0.32 seconds; tNow = 79000.0)
#    - Compute flexural isostasy 2.86 seconds
#    - Writing outputs (0.34 seconds; tNow = 80000.0)
#    - Compute flexural isostasy 3.21 seconds
#    - Writing outputs (0.35 seconds; tNow = 81000.0)
#    - Compute flexural isostasy 3.27 seconds
#    - Writing outputs (0.35 seconds; tNow = 82000.0)
#    - Compute flexural isostasy 3.37 seconds
#    - Writing outputs (0.34 seconds; tNow = 83000.0)
#    - Compute flexural isostasy 3.23 seconds
#    - Writing outputs (0.34 seconds; tNow = 84000.0)
#    - Compute flexural isostasy 3.36 seconds
#    - Writing outputs (0.36 seconds; tNow = 85000.0)
#    - Compute flexural isostasy 3.23 seconds
#    - Writing outputs (0.33 seconds; tNow = 86000.0)
#    - Compute flexural isostasy 3.05 seconds
#    - Writing outputs (0.36 seconds; tNow = 87000.0)
#    - Compute flexural isostasy 2.97 seconds
#    - Writing outputs (0.36 seconds; tNow = 88000.0)
#    - Compute flexural isostasy 3.86 seconds
#    - Writing outputs (0.37 seconds; tNow = 89000.0)
#    - Compute flexural isostasy 3.82 seconds
#    - Writing outputs (0.39 seconds; tNow = 90000.0)
#    - Compute flexural isostasy 3.89 seconds
#    - Writing outputs (0.36 seconds; tNow = 91000.0)
#    - Compute flexural isostasy 3.13 seconds
#    - Writing outputs (0.35 seconds; tNow = 92000.0)
#    - Compute flexural isostasy 3.51 seconds
#    - Writing outputs (0.34 seconds; tNow = 93000.0)
#    - Compute flexural isostasy 3.58 seconds
#    - Writing outputs (0.33 seconds; tNow = 94000.0)
#    - Compute flexural isostasy 3.02 seconds
#    - Writing outputs (0.33 seconds; tNow = 95000.0)
#    - Compute flexural isostasy 2.83 seconds
#    - Writing outputs (0.34 seconds; tNow = 96000.0)
#    - Compute flexural isostasy 3.20 seconds
#    - Writing outputs (0.34 seconds; tNow = 97000.0)
#    - Compute flexural isostasy 3.16 seconds
#    - Writing outputs (0.34 seconds; tNow = 98000.0)
#    - Compute flexural isostasy 4.52 seconds
#    - Writing outputs (0.40 seconds; tNow = 99000.0)
# tNow = 100000.0 (6.45 seconds)
#    - Compute flexural isostasy 3.72 seconds
#    - Writing outputs (0.36 seconds; tNow = 100000.0)
